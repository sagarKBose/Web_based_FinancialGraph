# %%
from pandas_datareader import data
import datetime
from bokeh.plotting import output_file,show,figure

# %%
start=datetime.datetime(2015,11,2)
end=datetime.datetime(2016,3,10)

df=data.DataReader(name="GOOG",data_source="yahoo",start=start,end=end)
#print(df)

# %%
def inc_dec(o,c):
    if c>o:
        value= "Increase"
    elif o>c:
        value="Decrease"
    else:
        value="Equal"
    return value
    
    
df["Status"]= [inc_dec(o,c) for o,c in zip(df.Open,df.Close)]
df["Middle"]=(df.Open+df.Close)/2
df["Height"]=abs(df.Close-df.Open)

# %%
df
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2015-11-02  721.619995  705.849976  711.059998  721.109985  1886300
# 2015-11-03  724.650024  714.719971  718.859985  722.159973  1565400
# 2015-11-04  733.099976  721.900024  722.000000  728.109985  1706700
# 2015-11-05  739.479980  729.469971  729.469971  731.250000  1861600
# 2015-11-06  735.409973  727.010010  731.500000  733.760010  1511600
# ...                ...         ...         ...         ...      ...
# 2016-03-04  716.489990  706.020020  714.989990  710.890015  1972100
# 2016-03-07  708.091003  686.900024  706.900024  695.159973  2985100
# 2016-03-08  703.789978  685.340027  688.590027  693.969971  2076300
# 2016-03-09  705.679993  694.000000  698.469971  705.239990  1421500
# 2016-03-10  716.440002  703.359985  708.119995  712.820007  2833500
#
#              Adj Close    Status      Middle     Height
# Date
# 2015-11-02  721.109985  Increase  716.084991  10.049988
# ...

# %%
f=figure(x_axis_type="datetime",width=1000,height=300,title="Candlestick Chart",sizing_mode="stretch_both")

w=12*60*60*1000


f.grid.grid_line_alpha=0.5
f.segment(df.index,df.High,df.index,df.Low,color="black")


f.rect(df.index[df.Status=="Increase"],df.Middle[df.Status=="Increase"],w,df.Height[df.Status=="Increase"],fill_color="#CCFFFF",line_color="black")
f.rect(df.index[df.Status=="Decrease"],df.Middle[df.Status=="Decrease"],w,df.Height[df.Status=="Decrease"],fill_color="#FF3333",line_color="black")
output_file("stock.html")
show(f)
